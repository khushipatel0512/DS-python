# %%
#section A 
#1. difference between .py and .ipynb files
# .py file 
# python script file
# it contains only code
# runs program
# used for software devlopment
# .ipynb file
# jupyter notebook file
# it contains code , output
# runs cell to cell
# used for DA and learning

# %%
#2.numerical vs categorial features
# numerical                                categorial
# conatins no. with values                 contains categorial or labels
# can be counted                           cannot be counted
# eg - age,bp,cholesterol                  eg- sex(M/F) , chest pain - type
